# %% [markdown]
# # Capstone Two Project :  Single Stock Predicting

# %% [raw]
# Recap Of This Data Science Project:
# The purpose of this project is to build a machine learning model which can predict a signal for a single stock. This model can indicates the investors whether buying a particular stock or not.

# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn import tree, metrics
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# # 2. Loading the data

# %% [raw]
# Data Source:
# https://www.kaggle.com/datasets/dgawlik/nyse

# %%
# import data
stocks= pd.read_csv('prices-split-adjusted.csv')
stocks
# Out:
#               date symbol        open       close         low        high  \
# 0       2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1       2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2       2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3       2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4       2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
# ...            ...    ...         ...         ...         ...         ...
# 851259  2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000
#
#            volume
# 0       2163600.0
# 1       2386400.0
# 2       2489500.0
# 3       2006300.0
# 4       1408600.0
# ...           ...
# 851259   973800.0
# 851260  1938100.0
# 851261  1701200.0
# 851262  1380900.0
# 851263   705100.0
#
# [851264 rows x 7 columns]

# %% [markdown]
# # 3. Data Wrangling

# %% [raw]
# Data wrangling is the process of converting raw data into a usable form.
# It may also be called data munging or data remediation.

# %%
# check the first 5 lines of data
stocks.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
# check the last 5 lines of data
stocks.tail()
# Out:
#               date symbol        open       close         low        high  \
# 851259  2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000
#
#            volume
# 851259   973800.0
# 851260  1938100.0
# 851261  1701200.0
# 851262  1380900.0
# 851263   705100.0

# %%
# Sort the stocks data by date
stocks = stocks.sort_values(by=['date'])
stocks
# Out:
#               date symbol       open      close        low       high  \
# 646     2010-01-04   SYMC  18.040001  18.400000  18.010000  18.530001
# 473     2010-01-04    IFF  41.509998  42.009998  41.500000  42.020000
# 474     2010-01-04   ILMN  31.120001  30.549999  30.420000  31.230000
# 475     2010-01-04   INTC  20.790001  20.879999  20.730000  21.030001
# 476     2010-01-04   INTU  31.090000  30.809999  30.770000  31.150000
# ...            ...    ...        ...        ...        ...        ...
# 850922  2016-12-30     ES  55.599998  55.230000  55.070000  55.740002
# 850921  2016-12-30    EQT  65.699997  65.400002  65.050003  66.470001
# 850920  2016-12-30    EQR  63.590000  64.360001  63.189999  64.440002
# 850933  2016-12-30    EXR  75.669998  77.239998  75.110001  77.300003
# 851263  2016-12-30    FTV  54.200001  53.630001  53.389999  54.480000
#
#             volume
# 646      8322300.0
# 473       286000.0
# 474      1793700.0
# 475     47800900.0
# 476      2353000.0
# ...            ...
# 850922   1446800.0
# 850921   1242100.0
# 850920   1534000.0
# 850933    884400.0
# 851263    705100.0
#
# [851264 rows x 7 columns]

# %%
# check the name of the columns
stocks.columns
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %%
#rename some columns to make it more recognizable
stocks.rename(columns={'symbol':'company'}, inplace=True)
stocks.head()
# Out:
#            date company       open      close    low       high      volume
# 646  2010-01-04    SYMC  18.040001  18.400000  18.01  18.530001   8322300.0
# 473  2010-01-04     IFF  41.509998  42.009998  41.50  42.020000    286000.0
# 474  2010-01-04    ILMN  31.120001  30.549999  30.42  31.230000   1793700.0
# 475  2010-01-04    INTC  20.790001  20.879999  20.73  21.030001  47800900.0
# 476  2010-01-04    INTU  31.090000  30.809999  30.77  31.150000   2353000.0

# %%
# check how many rows and columns
stocks.shape
# Out:
# (851264, 7)

# %%
# check the genal information about the data
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 851264 entries, 646 to 851263
# Data columns (total 7 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   date     851264 non-null  object
#  1   company  851264 non-null  object
#  2   open     851264 non-null  float64
#  3   close    851264 non-null  float64
#  4   low      851264 non-null  float64
#  5   high     851264 non-null  float64
#  6   volume   851264 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 52.0+ MB

# %%
# confirm if there is any null value
stocks.isnull().sum()
# Out:
# date       0
# company    0
# open       0
# close      0
# low        0
# high       0
# volume     0
# dtype: int64

# %%
# we can use stocks['column'].fillna(stocks['column'].mean(), inplace=True) to fill null value if there was any.
# stocks['column'].fillna(method='ffill', inplace=True)
# df.fillna(method='bfill', inplace=True)
# df.fillna(df.mean(numeric_only=True).round(1), inplace=True)  For mean
# df.fillna(df.median(numeric_only=True).round(1), inplace=True)  For median

# %%
# describe the data in statistic form
stocks.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       64.993618      65.011913      64.336541      65.639748
# std        75.203893      75.201216      74.459518      75.906861
# min         1.660000       1.590000       1.500000       1.810000
# 25%        31.270000      31.292776      30.940001      31.620001
# 50%        48.459999      48.480000      47.970001      48.959999
# 75%        75.120003      75.139999      74.400002      75.849998
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
# check of there is any duplicated data
stocks.duplicated().any()
# Out:
# False

# %%
# If the output is True, We can use stocks.drop_duplicates() to get rid of duplicated values

# %%
#check the unique value of some columns
stocks['company'].unique()
# Out:
# array(['SYMC', 'IFF', 'ILMN', 'INTC', 'INTU', 'IP', 'IPG', 'IR', 'IRM',
#        'IDXX', 'ISRG', 'IVZ', 'JBHT', 'JCI', 'JEC', 'JNJ', 'JNPR', 'JPM',
#        'JWN', 'ITW', 'K', 'ICE', 'HUM', 'HBAN', 'HBI', 'HCN', 'HCP', 'HD',
#        'HES', 'HIG', 'HOG', 'IBM', 'HOLX', 'HP', 'HPQ', 'HRB', 'HRL',
#        'HRS', 'HSIC', 'HST', 'HSY', 'HON', 'KEY', 'KIM', 'KLAC', 'M',
#        'MA', 'MAC', 'MAR', 'MAS', 'MAT', 'MCD', 'MCHP', 'LVLT', 'MCK',
#        'MDLZ', 'MDT', 'MET', 'MHK', 'MJN', 'MKC', 'MLM', 'MMC', 'MCO',
#        'LUV', 'LUK', 'LRCX', 'KMB', 'KMX', 'KO', 'KR', 'KSS', 'KSU', 'L',
#        'LB', 'LEG', 'LEN', 'LH', 'LKQ', 'LLL', 'LLTC', 'LLY', 'LMT',
#        'LNC', 'LNT', 'LOW', 'HAS', 'HAR', 'HAL', 'GWW', 'DTE', 'DUK',
#        'DVA', 'DVN', 'EA', 'EBAY', 'ECL', 'ED', 'DRI', 'EFX', 'EL', 'EMN',
#        'EMR', 'ENDP', 'EOG', 'EQIX', 'EQR', 'EQT', 'EIX', 'DPS', 'DOW',
#        'DOV', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE', 'DFS',
#        'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DISCA', 'DISCK', 'DLR', 'DLTR',
#        'DNB', 'ES', 'MMM', 'ESRX', 'ETFC', 'FRT', 'FSLR', 'FTI', 'FTR',
#        'GD', 'GE', 'GGP', 'GILD', 'FOXA', 'GIS', 'GOOG', 'GOOGL', 'GPC',
#        'GPN', 'GPS', 'GRMN', 'GS', 'GT', 'GLW', 'FOX', 'FMC', 'FLS',
#        'ETN', 'ETR', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FAST',
#        'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FL', 'FLIR',
#        'FLR', 'ESS', 'MNST', 'MO', 'MON', 'TJX', 'TMK', 'TMO', 'TROW',
#        'TRV', 'TSCO', 'TSN', 'TSO', 'TIF', 'TSS', 'TXN', 'TXT', 'UAA',
#        'UAL', 'UDR', 'UHS', 'ULTA', 'UNH', 'TWX', 'TGT', 'TGNA', 'TEL',
#        'SNI', 'SO', 'SPG', 'SPGI', 'SPLS', 'SRCL', 'SRE', 'STI', 'STT',
#        'STX', 'STZ', 'SWK', 'SWKS', 'SWN', 'SYK', 'SYY', 'T', 'TAP',
#        'TDC', 'UNM', 'SNA', 'UNP', 'URBN', 'WMB', 'WMT', 'WU', 'WY',
#        'WYN', 'WYNN', 'XEC', 'XEL', 'WM', 'XL', 'XOM', 'XRAY', 'XRX',
#        'YHOO', 'YUM', 'ZBH', 'ZION', 'AIV', 'XLNX', 'WHR', 'WFM', 'WFC',
#        'URI', 'USB', 'UTX', 'V', 'VAR', 'VFC', 'VIAB', 'VLO', 'VMC',
#        'VNO', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VZ', 'WAT', 'WBA', 'WDC',
#        'WEC', 'UPS', 'CTSH', 'SLG', 'SJM', 'NTRS', 'NUE', 'NVDA', 'NWL',
#        'O', 'OKE', 'OMC', 'ORCL', 'NTAP', 'ORLY', 'PAYX', 'PBCT', 'PBI',
#        'PCAR', 'PCG', 'PCLN', 'PDCO', 'PEG', 'OXY', 'NSC', 'NRG', 'NOV',
#        'MOS', 'MRK', 'MRO', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'MUR',
#        'MYL', 'NBL', 'NDAQ', 'NEE', 'NEM', 'NFLX', 'NFX', 'NI', 'NKE',
#        'NOC', 'PEP', 'SLB', 'PFE', 'PG', 'RF', 'RHI', 'RHT', 'RIG', 'RL',
#        'ROK', 'ROP', 'ROST', 'REGN', 'RRC', 'RTN', 'SBUX', 'SCG', 'SCHW',
#        'SE', 'SEE', 'SHW', 'SIG', 'RSG', 'RCL', 'RAI', 'R', 'PGR', 'PH',
#        'PHM', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'PPG', 'PPL',
#        'PRGO', 'PRU', 'PSA', 'PVH', 'PWR', 'PX', 'PXD', 'QCOM', 'PFG',
#        'CTL', 'MAA', 'CSX', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN',
#        'AN', 'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI',
#        'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'AMAT',
#        'ALXN', 'ALL', 'ALK', 'CTAS', 'A', 'AAL', 'AAP', 'AAPL', 'ABC',
#        'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'BAC', 'ADP', 'ADSK', 'AEE',
#        'AEP', 'AES', 'AET', 'AFL', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB',
#        'ADS', 'BAX', 'AGN', 'BBT', 'CHRW', 'CI', 'CINF', 'CL', 'CLX',
#        'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'COF', 'COG',
#        'COH', 'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'BBBY', 'CSCO',
#        'CHK', 'CHD', 'CNP', 'CERN', 'BCR', 'CF', 'BDX', 'BEN', 'BHI',
#        'BIIB', 'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'BK', 'CA',
#        'CELG', 'CCL', 'C', 'CCI', 'CBS', 'CBG', 'BBY', 'CB', 'CAT', 'CAH',
#        'CAG', 'CHTR', 'LYB', 'GM', 'KMI', 'KORS', 'DLPH', 'FB', 'FBHS',
#        'HCA', 'MPC', 'TRIP', 'TDG', 'XYL', 'NLSN', 'PSX', 'ABBV', 'ZTS',
#        'COTY', 'MNK', 'NWSA', 'NWS', 'EVHC', 'ALLE', 'SYF', 'NAVI',
#        'QRVO', 'CFG', 'WRK', 'KHC', 'PYPL', 'HPE', 'CSRA', 'WLTW', 'FTV'],
#       dtype=object)

# %%
# Isolate google stocks
google = stocks[stocks.company == 'GOOG']
google
# Out:
#               date company        open       close         low        high  \
# 439     2010-01-04    GOOG  312.304948  312.205308  310.955001  313.580158
# 907     2010-01-05    GOOG  312.419511  310.830459  309.610028  312.748278
# 1375    2010-01-06    GOOG  311.761979  302.994813  302.048370  311.761979
# 1843    2010-01-07    GOOG  303.562685  295.941242  295.218951  303.861575
# 2311    2010-01-08    GOOG  294.895159  299.886470  293.455551  300.499172
# ...            ...     ...         ...         ...         ...         ...
# 848963  2016-12-23    GOOG  790.900024  789.909973  787.280029  792.739990
# 849463  2016-12-27    GOOG  790.679993  791.549988  787.656982  797.859985
# 849963  2016-12-28    GOOG  793.700012  785.049988  783.200012  794.229980
# 850463  2016-12-29    GOOG  783.330017  782.789978  778.919983  785.929993
# 850963  2016-12-30    GOOG  782.750000  771.820007  770.409973  782.780029
#
#             volume
# 439      3927000.0
# 907      6031900.0
# 1375     7987100.0
# 1843    12876600.0
# 2311     9483900.0
# ...            ...
# 848963    623400.0
# 849463    789100.0
# 849963   1132700.0
# 850463    742200.0
# 850963   1760200.0
#
# [1762 rows x 7 columns]
